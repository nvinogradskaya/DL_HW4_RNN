# %% [markdown]
# <a href="https://colab.research.google.com/github/nvinogradskaya/DL_HW4_RNN/blob/main/Task2_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
from collections import Counter
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# обработка текста (в числовые значения // каждое слово - отдельный токен)

with open("anek_djvu.txt", "r", encoding="utf-8") as f:
    text = f.read()

text = text.lower()
tokens = text.split()

# словарь : ключи - слова из списка tokens, значения — кол-во их вхождений в текст
word_counts = Counter(tokens)
vocab = {word: idx for idx, (word, _) in enumerate(word_counts.items())}
reverse_vocab = {idx: word for word, idx in vocab.items()}

vocab_size = len(vocab)
print(f"размер словаря: {vocab_size}")

def text_to_sequence(text, vocab):
    return [vocab[word] for word in text.split() if word in vocab]

sequence = text_to_sequence(text, vocab)
# Out:
# размер словаря: 70355

# %%
# берем нужное количество токенов, разбиваем на test&train
max_tokens = 20000
sequence = sequence[:max_tokens]
seq_length = 30
X = []
y = []

for i in range(len(sequence) - seq_length):
    X.append(sequence[i:i+seq_length])
    y.append(sequence[i+seq_length])

X = torch.tensor(X, dtype=torch.long)
y = torch.tensor(y, dtype=torch.long)

train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# модель RNN
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class RNNModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(RNNModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x):
        embedded = self.embedding(x)
        rnn_out, _ = self.rnn(embedded)
        output = self.fc(rnn_out[:, -1, :])
        return output

# %%
# параметры модели и обучение

embedding_dim = 256
hidden_dim = 512
model = RNNModel(vocab_size, embedding_dim, hidden_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

batch_size = 128
num_epochs = 20
losses = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for i in range(0, len(X_train), batch_size):
        inputs = X_train[i:i+batch_size].to(device)
        targets = y_train[i:i+batch_size].to(device)

        optimizer.zero_grad()

        # прямой проход
        output = model(inputs)
        loss = criterion(output, targets)
        loss.backward()

        # обновляем параметры
        optimizer.step()
        total_loss += loss.item()
        if i % (batch_size * 10) == 0:
            print(f"epoch {epoch+1}/{num_epochs}, batch {i//batch_size}, loss: {loss.item():.4f}")

    avg_loss = total_loss / (len(X_train) // batch_size)
    losses.append(avg_loss)
    print(f"epoch {epoch+1}/{num_epochs}, avg Loss: {avg_loss:.4f}")
# Out:
# epoch 1/20, batch 0, loss: 11.5661
# epoch 1/20, batch 10, loss: 11.3489
# epoch 1/20, batch 20, loss: 10.5702
# epoch 1/20, batch 30, loss: 10.1701
# epoch 1/20, batch 40, loss: 9.5134
# epoch 1/20, batch 50, loss: 9.3610
# epoch 1/20, batch 60, loss: 10.5662
# epoch 1/20, batch 70, loss: 11.3872
# epoch 1/20, batch 80, loss: 10.6551
# epoch 1/20, batch 90, loss: 10.5515
# epoch 1/20, batch 100, loss: 10.0989
# epoch 1/20, batch 110, loss: 9.9087
# epoch 1/20, batch 120, loss: 10.7240
# epoch 1/20, avg Loss: 10.6294
# epoch 2/20, batch 0, loss: 9.1553
# epoch 2/20, batch 10, loss: 9.2927
# epoch 2/20, batch 20, loss: 9.7647
# epoch 2/20, batch 30, loss: 9.7232
# epoch 2/20, batch 40, loss: 8.7695
# epoch 2/20, batch 50, loss: 9.3973
# epoch 2/20, batch 60, loss: 10.2039
# epoch 2/20, batch 70, loss: 9.7333
# epoch 2/20, batch 80, loss: 8.8976
# epoch 2/20, batch 90, loss: 9.5165
# epoch 2/20, batch 100, loss: 8.9462
# epoch 2/20, batch 110, loss: 9.0425
# epoch 2/20, batch 120, loss: 9.3101
# epoch 2/20, avg Loss: 9.4705
# epoch 3/20, batch 0, loss: 8.3698
# epoch 3/20, batch 10, loss: 8.1278
# epoch 3/20, batch 20, loss: 8.2224
# epoch 3/20, batch 30, loss: 8.2024
# epoch 3/20, batch 40, loss: 7.5621
# epoch 3/20, batch 50, loss: 8.0900
# epoch 3/20, batch 60, loss: 10.1201
# epoch 3/20, batch 70, loss: 9.5733
# epoch 3/20, batch 80, loss: 9.4918
# epoch 3/20, batch 90, loss: 9.2007
# epoch 3/20, batch 100, loss: 8.9745
# epoch 3/20, batch 110, loss: 8.8402
# epoch 3/20, batch 120, loss: 8.9134
# epoch 3/20, avg Loss: 8.9583
# epoch 4/20, batch 0, loss: 7.8436
# epoch 4/20, batch 10, loss: 7.9855
# epoch 4/20, batch 20, loss: 8.4562
# epoch 4/20, batch 30, loss: 8.1218
# epoch 4/20, batch 40, loss: 7.8093
# epoch 4/20, batch 50, loss: 7.9651
# epoch 4/20, batch 60, loss: 8.6968
# epoch 4/20, batch 70, loss: 8.2281
# epoch 4/20, batch 80, loss: 8.2513
# epoch 4/20, batch 90, loss: 8.2381
# epoch 4/20, batch 100, loss: 7.9475
# epoch 4/20, batch 110, loss: 7.9482
# epoch 4/20, batch 120, loss: 8.3029
# epoch 4/20, avg Loss: 8.2743
# epoch 5/20, batch 0, loss: 7.3921
# epoch 5/20, batch 10, loss: 7.8394
# epoch 5/20, batch 20, loss: 7.6519
# epoch 5/20, batch 30, loss: 7.7329
# epoch 5/20, batch 40, loss: 7.3709
# epoch 5/20, batch 50, loss: 7.0554
# epoch 5/20, batch 60, loss: 7.9022
# epoch 5/20, batch 70, loss: 7.4803
# epoch 5/20, batch 80, loss: 7.9186
# epoch 5/20, batch 90, loss: 7.6024
# epoch 5/20, batch 100, loss: 7.2077
# epoch 5/20, batch 110, loss: 7.5132
# epoch 5/20, batch 120, loss: 7.4754
# epoch 5/20, avg Loss: 7.5754
# epoch 6/20, batch 0, loss: 6.8415
# epoch 6/20, batch 10, loss: 7.0541
# epoch 6/20, batch 20, loss: 7.1378
# epoch 6/20, batch 30, loss: 7.1039
# epoch 6/20, batch 40, loss: 6.7399
# epoch 6/20, batch 50, loss: 6.3102
# epoch 6/20, batch 60, loss: 6.9639
# epoch 6/20, batch 70, loss: 6.8936
# epoch 6/20, batch 80, loss: 7.1672
# epoch 6/20, batch 90, loss: 6.8061
# epoch 6/20, batch 100, loss: 6.5881
# epoch 6/20, batch 110, loss: 6.8348
# epoch 6/20, batch 120, loss: 6.7846
# epoch 6/20, avg Loss: 6.8892
# epoch 7/20, batch 0, loss: 5.9952
# epoch 7/20, batch 10, loss: 6.2792
# epoch 7/20, batch 20, loss: 6.3386
# epoch 7/20, batch 30, loss: 6.4711
# epoch 7/20, batch 40, loss: 5.9867
# epoch 7/20, batch 50, loss: 5.5742
# epoch 7/20, batch 60, loss: 6.0716
# epoch 7/20, batch 70, loss: 6.1087
# epoch 7/20, batch 80, loss: 6.3526
# epoch 7/20, batch 90, loss: 6.0282
# epoch 7/20, batch 100, loss: 5.8218
# epoch 7/20, batch 110, loss: 6.0426
# epoch 7/20, batch 120, loss: 6.0254
# epoch 7/20, avg Loss: 6.1231
# epoch 8/20, batch 0, loss: 5.0678
# epoch 8/20, batch 10, loss: 5.3673
# epoch 8/20, batch 20, loss: 5.5982
# epoch 8/20, batch 30, loss: 5.6381
# epoch 8/20, batch 40, loss: 5.2962
# epoch 8/20, batch 50, loss: 4.7423
# epoch 8/20, batch 60, loss: 5.1424
# epoch 8/20, batch 70, loss: 5.4032
# epoch 8/20, batch 80, loss: 5.4839
# epoch 8/20, batch 90, loss: 5.1385
# epoch 8/20, batch 100, loss: 5.1147
# epoch 8/20, batch 110, loss: 5.3418
# epoch 8/20, batch 120, loss: 5.1851
# epoch 8/20, avg Loss: 5.2821
# epoch 9/20, batch 0, loss: 4.1047
# epoch 9/20, batch 10, loss: 4.3632
# epoch 9/20, batch 20, loss: 4.6744
# epoch 9/20, batch 30, loss: 4.7743
# epoch 9/20, batch 40, loss: 4.3313
# epoch 9/20, batch 50, loss: 3.9554
# epoch 9/20, batch 60, loss: 4.1241
# epoch 9/20, batch 70, loss: 4.5902
# epoch 9/20, batch 80, loss: 4.4539
# epoch 9/20, batch 90, loss: 4.3636
# epoch 9/20, batch 100, loss: 4.2244
# epoch 9/20, batch 110, loss: 4.4742
# epoch 9/20, batch 120, loss: 4.3208
# epoch 9/20, avg Loss: 4.3601
# epoch 10/20, batch 0, loss: 3.2083
# epoch 10/20, batch 10, loss: 3.3975
# epoch 10/20, batch 20, loss: 3.7345
# epoch 10/20, batch 30, loss: 3.7741
# epoch 10/20, batch 40, loss: 3.4128
# epoch 10/20, batch 50, loss: 3.1308
# epoch 10/20, batch 60, loss: 3.2743
# epoch 10/20, batch 70, loss: 3.6965
# epoch 10/20, batch 80, loss: 3.5413
# epoch 10/20, batch 90, loss: 3.7042
# epoch 10/20, batch 100, loss: 3.4531
# epoch 10/20, batch 110, loss: 3.6025
# epoch 10/20, batch 120, loss: 3.5204
# epoch 10/20, avg Loss: 3.4511
# epoch 11/20, batch 0, loss: 2.7682
# epoch 11/20, batch 10, loss: 2.4908
# epoch 11/20, batch 20, loss: 2.9847
# epoch 11/20, batch 30, loss: 2.8506
# epoch 11/20, batch 40, loss: 2.6822
# epoch 11/20, batch 50, loss: 2.5755
# epoch 11/20, batch 60, loss: 2.4754
# epoch 11/20, batch 70, loss: 2.9599
# epoch 11/20, batch 80, loss: 2.6243
# epoch 11/20, batch 90, loss: 2.7486
# epoch 11/20, batch 100, loss: 2.7138
# epoch 11/20, batch 110, loss: 2.7768
# epoch 11/20, batch 120, loss: 2.4976
# epoch 11/20, avg Loss: 2.6458
# epoch 12/20, batch 0, loss: 2.0677
# epoch 12/20, batch 10, loss: 2.0191
# epoch 12/20, batch 20, loss: 2.2984
# epoch 12/20, batch 30, loss: 2.0554
# epoch 12/20, batch 40, loss: 2.1319
# epoch 12/20, batch 50, loss: 2.0525
# epoch 12/20, batch 60, loss: 1.8684
# epoch 12/20, batch 70, loss: 2.2402
# epoch 12/20, batch 80, loss: 1.9092
# epoch 12/20, batch 90, loss: 2.1811
# epoch 12/20, batch 100, loss: 2.0727
# epoch 12/20, batch 110, loss: 2.2613
# epoch 12/20, batch 120, loss: 2.0703
# epoch 12/20, avg Loss: 2.0473
# epoch 13/20, batch 0, loss: 1.5025
# epoch 13/20, batch 10, loss: 1.4625
# epoch 13/20, batch 20, loss: 1.7480
# epoch 13/20, batch 30, loss: 1.7087
# epoch 13/20, batch 40, loss: 1.6580
# epoch 13/20, batch 50, loss: 1.5229
# epoch 13/20, batch 60, loss: 1.4300
# epoch 13/20, batch 70, loss: 1.8101
# epoch 13/20, batch 80, loss: 1.4890
# epoch 13/20, batch 90, loss: 1.7497
# epoch 13/20, batch 100, loss: 1.6975
# epoch 13/20, batch 110, loss: 1.7079
# epoch 13/20, batch 120, loss: 1.6484
# epoch 13/20, avg Loss: 1.5933
# epoch 14/20, batch 0, loss: 1.3172
# epoch 14/20, batch 10, loss: 0.9472
# epoch 14/20, batch 20, loss: 1.2477
# epoch 14/20, batch 30, loss: 1.3580
# epoch 14/20, batch 40, loss: 1.4128
# epoch 14/20, batch 50, loss: 1.2159
# epoch 14/20, batch 60, loss: 1.2403
# epoch 14/20, batch 70, loss: 1.4430
# epoch 14/20, batch 80, loss: 1.1657
# epoch 14/20, batch 90, loss: 1.3126
# epoch 14/20, batch 100, loss: 1.2969
# epoch 14/20, batch 110, loss: 1.2322
# epoch 14/20, batch 120, loss: 1.2319
# epoch 14/20, avg Loss: 1.2359
# epoch 15/20, batch 0, loss: 0.9600
# epoch 15/20, batch 10, loss: 0.7223
# epoch 15/20, batch 20, loss: 0.9761
# epoch 15/20, batch 30, loss: 1.1217
# epoch 15/20, batch 40, loss: 1.0858
# epoch 15/20, batch 50, loss: 0.9718
# epoch 15/20, batch 60, loss: 0.8812
# epoch 15/20, batch 70, loss: 1.1267
# epoch 15/20, batch 80, loss: 0.8525
# epoch 15/20, batch 90, loss: 1.0649
# epoch 15/20, batch 100, loss: 1.0790
# epoch 15/20, batch 110, loss: 1.1100
# epoch 15/20, batch 120, loss: 0.9315
# epoch 15/20, avg Loss: 0.9683
# epoch 16/20, batch 0, loss: 0.7775
# epoch 16/20, batch 10, loss: 0.5197
# epoch 16/20, batch 20, loss: 0.7258
# epoch 16/20, batch 30, loss: 0.6888
# epoch 16/20, batch 40, loss: 0.7115
# epoch 16/20, batch 50, loss: 0.8114
# epoch 16/20, batch 60, loss: 0.5761
# epoch 16/20, batch 70, loss: 0.9844
# epoch 16/20, batch 80, loss: 0.7327
# epoch 16/20, batch 90, loss: 0.7332
# epoch 16/20, batch 100, loss: 0.7128
# epoch 16/20, batch 110, loss: 0.9206
# epoch 16/20, batch 120, loss: 0.6535
# epoch 16/20, avg Loss: 0.7005
# epoch 17/20, batch 0, loss: 0.5645
# epoch 17/20, batch 10, loss: 0.3607
# epoch 17/20, batch 20, loss: 0.5347
# epoch 17/20, batch 30, loss: 0.5706
# epoch 17/20, batch 40, loss: 0.6810
# epoch 17/20, batch 50, loss: 0.6757
# epoch 17/20, batch 60, loss: 0.5519
# epoch 17/20, batch 70, loss: 0.7641
# epoch 17/20, batch 80, loss: 0.4729
# epoch 17/20, batch 90, loss: 0.5904
# epoch 17/20, batch 100, loss: 0.5209
# epoch 17/20, batch 110, loss: 0.5677
# epoch 17/20, batch 120, loss: 0.6077
# epoch 17/20, avg Loss: 0.5687
# epoch 18/20, batch 0, loss: 0.6152
# epoch 18/20, batch 10, loss: 0.2835
# epoch 18/20, batch 20, loss: 0.4435
# epoch 18/20, batch 30, loss: 0.4066
# epoch 18/20, batch 40, loss: 0.4702
# epoch 18/20, batch 50, loss: 0.3641
# epoch 18/20, batch 60, loss: 0.5097
# epoch 18/20, batch 70, loss: 0.5365
# epoch 18/20, batch 80, loss: 0.5001
# epoch 18/20, batch 90, loss: 0.6371
# epoch 18/20, batch 100, loss: 0.5792
# epoch 18/20, batch 110, loss: 0.5030
# epoch 18/20, batch 120, loss: 0.4059
# epoch 18/20, avg Loss: 0.4689
# epoch 19/20, batch 0, loss: 0.3709
# epoch 19/20, batch 10, loss: 0.2249
# epoch 19/20, batch 20, loss: 0.3348
# epoch 19/20, batch 30, loss: 0.3255
# epoch 19/20, batch 40, loss: 0.3293
# epoch 19/20, batch 50, loss: 0.3341
# epoch 19/20, batch 60, loss: 0.2579
# epoch 19/20, batch 70, loss: 0.3927
# epoch 19/20, batch 80, loss: 0.2674
# epoch 19/20, batch 90, loss: 0.3299
# epoch 19/20, batch 100, loss: 0.3060
# epoch 19/20, batch 110, loss: 0.3249
# epoch 19/20, batch 120, loss: 0.3400
# epoch 19/20, avg Loss: 0.3148
# epoch 20/20, batch 0, loss: 0.3082
# epoch 20/20, batch 10, loss: 0.1533
# epoch 20/20, batch 20, loss: 0.2143
# epoch 20/20, batch 30, loss: 0.1739
# epoch 20/20, batch 40, loss: 0.2092
# epoch 20/20, batch 50, loss: 0.1795
# epoch 20/20, batch 60, loss: 0.1567
# epoch 20/20, batch 70, loss: 0.2369
# epoch 20/20, batch 80, loss: 0.1821
# epoch 20/20, batch 90, loss: 0.2359
# epoch 20/20, batch 100, loss: 0.2166
# epoch 20/20, batch 110, loss: 0.1637
# epoch 20/20, batch 120, loss: 0.1334
# epoch 20/20, avg Loss: 0.1969

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, num_epochs+1), losses)
plt.xlabel('эпохи')
plt.ylabel('лосс')
plt.title('rnn')
plt.show()

# %%
# сгенерируем какой нибудь текст
def generate_text(model, start_text, length=50):
    model.eval()
    words = start_text.split()
    inputs = torch.tensor(text_to_sequence(' '.join(words), vocab), dtype=torch.long).unsqueeze(0).to(device)
    generated_text = start_text
    with torch.no_grad():
        for _ in range(length):
            output = model(inputs)
            # предсказание след. слова
            _, predicted_idx = torch.max(output, dim=1)
            predicted_word = reverse_vocab[predicted_idx.item()]
            generated_text += ' ' + predicted_word

            words.append(predicted_word)
            inputs = torch.tensor(text_to_sequence(' '.join(words[-seq_length:]), vocab), dtype=torch.long).unsqueeze(0).to(device)

    return generated_text

start_text = "сегодня в анекдоте"
generated_text = generate_text(model, start_text)
print(generated_text)
# Out:
# сегодня в анекдоте белом?- сдаюсь, любимый. <|startoftext|>- сейчас врачи действуют по протоколу.- а раньше?- раньше лечили. <|startoftext|>самозатачивающихся ножей в природе не существует, их придумали жены, чтобы не объяснять мужьям, кто точит ножи. <|startoftext|>- вам сладкий попкорн или соленый?- такой же, как моя девушка.- недожаренный? <|startoftext|>чем больше правил, тем больше возможности их нарушать! <|startoftext|>раньше

# %%
# улучшим модель (добавим ограничение на переобучение и умножим hidden_dim на 2 для двунаправленной RNN)
class ImprovedRNNModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, dropout_rate=0.5):
        super(ImprovedRNNModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(hidden_dim * 2, vocab_size)

    def forward(self, x):
        embedded = self.embedding(x)
        rnn_out, _ = self.rnn(embedded)
        rnn_out = self.dropout(rnn_out)
        output = self.fc(rnn_out[:, -1, :])
        return output

# %%
# параметры модели и обучение
embedding_dim = 256
hidden_dim = 512
model = ImprovedRNNModel(vocab_size, embedding_dim, hidden_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

batch_size = 128
num_epochs = 20
losses = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for i in range(0, len(X_train), batch_size):
        inputs = X_train[i:i+batch_size].to(device)
        targets = y_train[i:i+batch_size].to(device)

        optimizer.zero_grad()
        output = model(inputs)

        loss = criterion(output, targets)
        loss.backward()

        optimizer.step()
        total_loss += loss.item()
        if i % (batch_size * 10) == 0:
            print(f"epoch {epoch+1}/{num_epochs}, batch {i//batch_size}, loss: {loss.item():.4f}")

    avg_loss = total_loss / (len(X_train) // batch_size)
    losses.append(avg_loss)
    print(f"epoch {epoch+1}/{num_epochs}, avg Loss: {avg_loss:.4f}")
# Out:
# epoch 1/20, batch 0, loss: 11.5403
# epoch 1/20, batch 10, loss: 11.4282
# epoch 1/20, batch 20, loss: 10.0451
# epoch 1/20, batch 30, loss: 9.8126
# epoch 1/20, batch 40, loss: 9.1966
# epoch 1/20, batch 50, loss: 9.2155
# epoch 1/20, batch 60, loss: 10.2860
# epoch 1/20, batch 70, loss: 9.5461
# epoch 1/20, batch 80, loss: 10.6385
# epoch 1/20, batch 90, loss: 10.6966
# epoch 1/20, batch 100, loss: 9.9232
# epoch 1/20, batch 110, loss: 9.6548
# epoch 1/20, batch 120, loss: 10.2188
# epoch 1/20, avg Loss: 10.2239
# epoch 2/20, batch 0, loss: 9.1016
# epoch 2/20, batch 10, loss: 9.7295
# epoch 2/20, batch 20, loss: 9.4321
# epoch 2/20, batch 30, loss: 9.6254
# epoch 2/20, batch 40, loss: 8.1554
# epoch 2/20, batch 50, loss: 9.6934
# epoch 2/20, batch 60, loss: 9.6080
# epoch 2/20, batch 70, loss: 8.4967
# epoch 2/20, batch 80, loss: 9.4487
# epoch 2/20, batch 90, loss: 8.7727
# epoch 2/20, batch 100, loss: 8.5894
# epoch 2/20, batch 110, loss: 8.7875
# epoch 2/20, batch 120, loss: 9.0523
# epoch 2/20, avg Loss: 9.2304
# epoch 3/20, batch 0, loss: 7.6404
# epoch 3/20, batch 10, loss: 8.4958
# epoch 3/20, batch 20, loss: 7.7083
# epoch 3/20, batch 30, loss: 7.9872
# epoch 3/20, batch 40, loss: 7.8351
# epoch 3/20, batch 50, loss: 7.6038
# epoch 3/20, batch 60, loss: 8.2193
# epoch 3/20, batch 70, loss: 7.5664
# epoch 3/20, batch 80, loss: 8.1460
# epoch 3/20, batch 90, loss: 7.6338
# epoch 3/20, batch 100, loss: 7.6855
# epoch 3/20, batch 110, loss: 7.7055
# epoch 3/20, batch 120, loss: 8.2162
# epoch 3/20, avg Loss: 7.8885
# epoch 4/20, batch 0, loss: 6.6148
# epoch 4/20, batch 10, loss: 6.8754
# epoch 4/20, batch 20, loss: 6.7688
# epoch 4/20, batch 30, loss: 6.8261
# epoch 4/20, batch 40, loss: 6.8421
# epoch 4/20, batch 50, loss: 6.4172
# epoch 4/20, batch 60, loss: 6.5676
# epoch 4/20, batch 70, loss: 6.5967
# epoch 4/20, batch 80, loss: 6.7559
# epoch 4/20, batch 90, loss: 6.6338
# epoch 4/20, batch 100, loss: 6.4057
# epoch 4/20, batch 110, loss: 6.5338
# epoch 4/20, batch 120, loss: 7.0512
# epoch 4/20, avg Loss: 6.7705
# epoch 5/20, batch 0, loss: 5.4697
# epoch 5/20, batch 10, loss: 5.8280
# epoch 5/20, batch 20, loss: 5.6930
# epoch 5/20, batch 30, loss: 5.8542
# epoch 5/20, batch 40, loss: 5.8884
# epoch 5/20, batch 50, loss: 5.4331
# epoch 5/20, batch 60, loss: 5.2387
# epoch 5/20, batch 70, loss: 5.6367
# epoch 5/20, batch 80, loss: 5.5813
# epoch 5/20, batch 90, loss: 5.3116
# epoch 5/20, batch 100, loss: 5.2505
# epoch 5/20, batch 110, loss: 5.4614
# epoch 5/20, batch 120, loss: 5.5415
# epoch 5/20, avg Loss: 5.6040
# epoch 6/20, batch 0, loss: 4.7770
# epoch 6/20, batch 10, loss: 4.4001
# epoch 6/20, batch 20, loss: 4.4084
# epoch 6/20, batch 30, loss: 4.8350
# epoch 6/20, batch 40, loss: 5.0985
# epoch 6/20, batch 50, loss: 4.5969
# epoch 6/20, batch 60, loss: 4.4333
# epoch 6/20, batch 70, loss: 4.7610
# epoch 6/20, batch 80, loss: 4.3429
# epoch 6/20, batch 90, loss: 4.5933
# epoch 6/20, batch 100, loss: 4.5267
# epoch 6/20, batch 110, loss: 4.4786
# epoch 6/20, batch 120, loss: 4.4627
# epoch 6/20, avg Loss: 4.5663
# epoch 7/20, batch 0, loss: 3.9193
# epoch 7/20, batch 10, loss: 3.7945
# epoch 7/20, batch 20, loss: 3.7847
# epoch 7/20, batch 30, loss: 4.0338
# epoch 7/20, batch 40, loss: 4.3605
# epoch 7/20, batch 50, loss: 4.0399
# epoch 7/20, batch 60, loss: 3.8460
# epoch 7/20, batch 70, loss: 3.8082
# epoch 7/20, batch 80, loss: 3.9746
# epoch 7/20, batch 90, loss: 3.8681
# epoch 7/20, batch 100, loss: 3.7476
# epoch 7/20, batch 110, loss: 3.8063
# epoch 7/20, batch 120, loss: 4.0603
# epoch 7/20, avg Loss: 3.9143
# epoch 8/20, batch 0, loss: 3.2952
# epoch 8/20, batch 10, loss: 2.8983
# epoch 8/20, batch 20, loss: 3.3931
# epoch 8/20, batch 30, loss: 3.8788
# epoch 8/20, batch 40, loss: 4.0485
# epoch 8/20, batch 50, loss: 3.7044
# epoch 8/20, batch 60, loss: 3.5679
# epoch 8/20, batch 70, loss: 4.0803
# epoch 8/20, batch 80, loss: 3.8189
# epoch 8/20, batch 90, loss: 4.0490
# epoch 8/20, batch 100, loss: 3.9577
# epoch 8/20, batch 110, loss: 3.8111
# epoch 8/20, batch 120, loss: 3.6679
# epoch 8/20, avg Loss: 3.7187
# epoch 9/20, batch 0, loss: 3.4988
# epoch 9/20, batch 10, loss: 2.5929
# epoch 9/20, batch 20, loss: 3.1356
# epoch 9/20, batch 30, loss: 3.3299
# epoch 9/20, batch 40, loss: 3.8143
# epoch 9/20, batch 50, loss: 3.4216
# epoch 9/20, batch 60, loss: 2.9956
# epoch 9/20, batch 70, loss: 3.4645
# epoch 9/20, batch 80, loss: 3.0293
# epoch 9/20, batch 90, loss: 3.5616
# epoch 9/20, batch 100, loss: 3.2946
# epoch 9/20, batch 110, loss: 3.5282
# epoch 9/20, batch 120, loss: 3.1218
# epoch 9/20, avg Loss: 3.2527
# epoch 10/20, batch 0, loss: 3.1033
# epoch 10/20, batch 10, loss: 2.5155
# epoch 10/20, batch 20, loss: 2.7569
# epoch 10/20, batch 30, loss: 3.0806
# epoch 10/20, batch 40, loss: 3.1296
# epoch 10/20, batch 50, loss: 2.9781
# epoch 10/20, batch 60, loss: 2.4282
# epoch 10/20, batch 70, loss: 2.9589
# epoch 10/20, batch 80, loss: 2.5941
# epoch 10/20, batch 90, loss: 2.9352
# epoch 10/20, batch 100, loss: 2.8555
# epoch 10/20, batch 110, loss: 3.0130
# epoch 10/20, batch 120, loss: 2.5844
# epoch 10/20, avg Loss: 2.8242
# epoch 11/20, batch 0, loss: 2.6317
# epoch 11/20, batch 10, loss: 2.0275
# epoch 11/20, batch 20, loss: 2.4742
# epoch 11/20, batch 30, loss: 2.5930
# epoch 11/20, batch 40, loss: 2.9029
# epoch 11/20, batch 50, loss: 2.6405
# epoch 11/20, batch 60, loss: 2.2161
# epoch 11/20, batch 70, loss: 2.5340
# epoch 11/20, batch 80, loss: 2.2688
# epoch 11/20, batch 90, loss: 2.6405
# epoch 11/20, batch 100, loss: 2.6425
# epoch 11/20, batch 110, loss: 2.8016
# epoch 11/20, batch 120, loss: 2.5006
# epoch 11/20, avg Loss: 2.4677
# epoch 12/20, batch 0, loss: 2.3643
# epoch 12/20, batch 10, loss: 1.7899
# epoch 12/20, batch 20, loss: 2.1908
# epoch 12/20, batch 30, loss: 2.1926
# epoch 12/20, batch 40, loss: 2.5554
# epoch 12/20, batch 50, loss: 2.1862
# epoch 12/20, batch 60, loss: 2.1217
# epoch 12/20, batch 70, loss: 2.2866
# epoch 12/20, batch 80, loss: 2.2175
# epoch 12/20, batch 90, loss: 2.4904
# epoch 12/20, batch 100, loss: 2.5946
# epoch 12/20, batch 110, loss: 2.5894
# epoch 12/20, batch 120, loss: 2.3928
# epoch 12/20, avg Loss: 2.2340
# epoch 13/20, batch 0, loss: 2.2991
# epoch 13/20, batch 10, loss: 1.7476
# epoch 13/20, batch 20, loss: 1.6497
# epoch 13/20, batch 30, loss: 2.1342
# epoch 13/20, batch 40, loss: 2.1376
# epoch 13/20, batch 50, loss: 1.9324
# epoch 13/20, batch 60, loss: 1.6980
# epoch 13/20, batch 70, loss: 2.0429
# epoch 13/20, batch 80, loss: 1.9180
# epoch 13/20, batch 90, loss: 2.1166
# epoch 13/20, batch 100, loss: 2.0841
# epoch 13/20, batch 110, loss: 2.0998
# epoch 13/20, batch 120, loss: 1.8551
# epoch 13/20, avg Loss: 1.9181
# epoch 14/20, batch 0, loss: 1.8189
# epoch 14/20, batch 10, loss: 1.3418
# epoch 14/20, batch 20, loss: 1.6393
# epoch 14/20, batch 30, loss: 1.6143
# epoch 14/20, batch 40, loss: 1.9325
# epoch 14/20, batch 50, loss: 1.6695
# epoch 14/20, batch 60, loss: 1.4543
# epoch 14/20, batch 70, loss: 1.9370
# epoch 14/20, batch 80, loss: 1.4510
# epoch 14/20, batch 90, loss: 1.7113
# epoch 14/20, batch 100, loss: 1.6732
# epoch 14/20, batch 110, loss: 2.2056
# epoch 14/20, batch 120, loss: 1.6280
# epoch 14/20, avg Loss: 1.6816
# epoch 15/20, batch 0, loss: 1.6449
# epoch 15/20, batch 10, loss: 1.1842
# epoch 15/20, batch 20, loss: 1.4056
# epoch 15/20, batch 30, loss: 1.4166
# epoch 15/20, batch 40, loss: 1.4981
# epoch 15/20, batch 50, loss: 1.5004
# epoch 15/20, batch 60, loss: 1.1735
# epoch 15/20, batch 70, loss: 1.6464
# epoch 15/20, batch 80, loss: 1.3270
# epoch 15/20, batch 90, loss: 1.5601
# epoch 15/20, batch 100, loss: 1.5452
# epoch 15/20, batch 110, loss: 2.0041
# epoch 15/20, batch 120, loss: 1.7997
# epoch 15/20, avg Loss: 1.5009
# epoch 16/20, batch 0, loss: 2.1968
# epoch 16/20, batch 10, loss: 1.6301
# epoch 16/20, batch 20, loss: 1.6341
# epoch 16/20, batch 30, loss: 1.7698
# epoch 16/20, batch 40, loss: 1.8979
# epoch 16/20, batch 50, loss: 1.7371
# epoch 16/20, batch 60, loss: 1.3250
# epoch 16/20, batch 70, loss: 1.7032
# epoch 16/20, batch 80, loss: 1.4115
# epoch 16/20, batch 90, loss: 1.7942
# epoch 16/20, batch 100, loss: 1.7881
# epoch 16/20, batch 110, loss: 1.8440
# epoch 16/20, batch 120, loss: 1.3682
# epoch 16/20, avg Loss: 1.7098
# epoch 17/20, batch 0, loss: 1.6193
# epoch 17/20, batch 10, loss: 1.1732
# epoch 17/20, batch 20, loss: 1.1110
# epoch 17/20, batch 30, loss: 1.2947
# epoch 17/20, batch 40, loss: 1.4045
# epoch 17/20, batch 50, loss: 1.2303
# epoch 17/20, batch 60, loss: 1.0035
# epoch 17/20, batch 70, loss: 1.5112
# epoch 17/20, batch 80, loss: 0.9741
# epoch 17/20, batch 90, loss: 1.3123
# epoch 17/20, batch 100, loss: 1.3199
# epoch 17/20, batch 110, loss: 1.4405
# epoch 17/20, batch 120, loss: 1.2710
# epoch 17/20, avg Loss: 1.2497
# epoch 18/20, batch 0, loss: 1.1362
# epoch 18/20, batch 10, loss: 0.8854
# epoch 18/20, batch 20, loss: 0.8889
# epoch 18/20, batch 30, loss: 1.1930
# epoch 18/20, batch 40, loss: 1.2083
# epoch 18/20, batch 50, loss: 1.1390
# epoch 18/20, batch 60, loss: 0.6901
# epoch 18/20, batch 70, loss: 1.0262
# epoch 18/20, batch 80, loss: 0.8773
# epoch 18/20, batch 90, loss: 1.1399
# epoch 18/20, batch 100, loss: 1.2090
# epoch 18/20, batch 110, loss: 1.4074
# epoch 18/20, batch 120, loss: 1.0082
# epoch 18/20, avg Loss: 1.0117
# epoch 19/20, batch 0, loss: 0.9372
# epoch 19/20, batch 10, loss: 0.7365
# epoch 19/20, batch 20, loss: 0.8467
# epoch 19/20, batch 30, loss: 0.9051
# epoch 19/20, batch 40, loss: 1.0211
# epoch 19/20, batch 50, loss: 0.9591
# epoch 19/20, batch 60, loss: 0.6604
# epoch 19/20, batch 70, loss: 1.0533
# epoch 19/20, batch 80, loss: 0.7593
# epoch 19/20, batch 90, loss: 0.9635
# epoch 19/20, batch 100, loss: 1.0972
# epoch 19/20, batch 110, loss: 1.1218
# epoch 19/20, batch 120, loss: 0.7813
# epoch 19/20, avg Loss: 0.8599
# epoch 20/20, batch 0, loss: 0.8738
# epoch 20/20, batch 10, loss: 0.5504
# epoch 20/20, batch 20, loss: 0.5075
# epoch 20/20, batch 30, loss: 0.7652
# epoch 20/20, batch 40, loss: 0.9865
# epoch 20/20, batch 50, loss: 0.6990
# epoch 20/20, batch 60, loss: 0.5697
# epoch 20/20, batch 70, loss: 0.9422
# epoch 20/20, batch 80, loss: 0.6457
# epoch 20/20, batch 90, loss: 0.7312
# epoch 20/20, batch 100, loss: 0.7897
# epoch 20/20, batch 110, loss: 0.9339
# epoch 20/20, batch 120, loss: 0.7551
# epoch 20/20, avg Loss: 0.7506

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, num_epochs+1), losses)
plt.xlabel('эпохи')
plt.ylabel('лосс')
plt.title('improved rnn')
plt.show()

# %%
# сгенерируем текст
def generate_text(model, start_text, length=50):
    model.eval()
    words = start_text.split()
    inputs = torch.tensor(text_to_sequence(' '.join(words), vocab), dtype=torch.long).unsqueeze(0).to(device)

    generated_text = start_text

    with torch.no_grad():
        for _ in range(length):
            output = model(inputs)
            _, predicted_idx = torch.max(output, dim=1)
            predicted_word = reverse_vocab[predicted_idx.item()]
            generated_text += ' ' + predicted_word
            words.append(predicted_word)
            inputs = torch.tensor(text_to_sequence(' '.join(words[-seq_length:]), vocab), dtype=torch.long).unsqueeze(0).to(device)

    return generated_text

start_text = "сегодня в анекдоте"
generated_text = generate_text(model, start_text)
print(generated_text)
# Out:
# сегодня в анекдоте белом?- сдаюсь, любимый. <|startoftext|>- как вы думаете, фаберже был популярен среди женщин?- безусловно! его в стране царь. выше него рулит - это воровство и бандитизм. а потом садись и отдыхай с грустью:- как моя девушка.- недожаренный? <|startoftext|>чем х@евей квартира, тем больше требований к навальному приехали послы множества стран. послы сказали,

# %%
#  LSTM
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers=2):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x):
        embedded = self.embedding(x)
        lstm_out, _ = self.lstm(embedded)
        output = self.fc(lstm_out[:, -1, :])  # Используем выход последнего времени
        return output

# %%
# параметры + обучение
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
embedding_dim = 256
hidden_dim = 512
num_layers = 2
model = LSTMModel(vocab_size, embedding_dim, hidden_dim, num_layers).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

batch_size = 128
num_epochs = 20
losses = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for i in range(0, len(X_train), batch_size):
        inputs = X_train[i:i + batch_size].to(device)
        targets = y_train[i:i + batch_size].to(device)

        optimizer.zero_grad()

        output = model(inputs)
        loss = criterion(output, targets)
        loss.backward()

        optimizer.step()
        total_loss += loss.item()

        if i % (batch_size * 10) == 0:
            print(f"epoch {epoch+1}/{num_epochs}, batch {i//batch_size}, loss: {loss.item():.4f}")

    avg_loss = total_loss / (len(X_train) // batch_size)
    losses.append(avg_loss)
    print(f"epoch {epoch+1}/{num_epochs}, avg Loss: {avg_loss:.4f}")
# Out:
# epoch 1/20, batch 0, loss: 11.1570
# epoch 1/20, batch 10, loss: 10.0196
# epoch 1/20, batch 20, loss: 9.7552
# epoch 1/20, batch 30, loss: 9.5806
# epoch 1/20, batch 40, loss: 9.2983
# epoch 1/20, batch 50, loss: 9.3770
# epoch 1/20, batch 60, loss: 9.7973
# epoch 1/20, batch 70, loss: 9.1943
# epoch 1/20, batch 80, loss: 9.5968
# epoch 1/20, batch 90, loss: 9.0031
# epoch 1/20, batch 100, loss: 8.9388
# epoch 1/20, batch 110, loss: 8.8745
# epoch 1/20, batch 120, loss: 9.1906
# epoch 1/20, avg Loss: 9.6018
# epoch 2/20, batch 0, loss: 8.0350
# epoch 2/20, batch 10, loss: 7.6305
# epoch 2/20, batch 20, loss: 7.7144
# epoch 2/20, batch 30, loss: 7.8760
# epoch 2/20, batch 40, loss: 7.7269
# epoch 2/20, batch 50, loss: 7.8119
# epoch 2/20, batch 60, loss: 8.4056
# epoch 2/20, batch 70, loss: 8.1568
# epoch 2/20, batch 80, loss: 8.6709
# epoch 2/20, batch 90, loss: 8.2905
# epoch 2/20, batch 100, loss: 8.3054
# epoch 2/20, batch 110, loss: 8.3405
# epoch 2/20, batch 120, loss: 8.6456
# epoch 2/20, avg Loss: 8.2257
# epoch 3/20, batch 0, loss: 7.7518
# epoch 3/20, batch 10, loss: 7.7594
# epoch 3/20, batch 20, loss: 7.6847
# epoch 3/20, batch 30, loss: 7.9177
# epoch 3/20, batch 40, loss: 7.7364
# epoch 3/20, batch 50, loss: 7.6734
# epoch 3/20, batch 60, loss: 8.1353
# epoch 3/20, batch 70, loss: 7.6502
# epoch 3/20, batch 80, loss: 8.1875
# epoch 3/20, batch 90, loss: 7.8580
# epoch 3/20, batch 100, loss: 7.8667
# epoch 3/20, batch 110, loss: 7.9287
# epoch 3/20, batch 120, loss: 8.2405
# epoch 3/20, avg Loss: 7.9644
# epoch 4/20, batch 0, loss: 7.5447
# epoch 4/20, batch 10, loss: 7.8329
# epoch 4/20, batch 20, loss: 7.6530
# epoch 4/20, batch 30, loss: 7.4481
# epoch 4/20, batch 40, loss: 7.4663
# epoch 4/20, batch 50, loss: 7.2984
# epoch 4/20, batch 60, loss: 7.6221
# epoch 4/20, batch 70, loss: 7.8058
# epoch 4/20, batch 80, loss: 8.3374
# epoch 4/20, batch 90, loss: 7.6591
# epoch 4/20, batch 100, loss: 7.5883
# epoch 4/20, batch 110, loss: 7.7166
# epoch 4/20, batch 120, loss: 7.8225
# epoch 4/20, avg Loss: 7.7477
# epoch 5/20, batch 0, loss: 7.5679
# epoch 5/20, batch 10, loss: 7.6816
# epoch 5/20, batch 20, loss: 7.5386
# epoch 5/20, batch 30, loss: 7.5382
# epoch 5/20, batch 40, loss: 7.2900
# epoch 5/20, batch 50, loss: 7.3582
# epoch 5/20, batch 60, loss: 7.5630
# epoch 5/20, batch 70, loss: 7.5891
# epoch 5/20, batch 80, loss: 7.7673
# epoch 5/20, batch 90, loss: 7.4374
# epoch 5/20, batch 100, loss: 7.3529
# epoch 5/20, batch 110, loss: 7.5004
# epoch 5/20, batch 120, loss: 7.6403
# epoch 5/20, avg Loss: 7.5707
# epoch 6/20, batch 0, loss: 7.1778
# epoch 6/20, batch 10, loss: 7.3601
# epoch 6/20, batch 20, loss: 7.2205
# epoch 6/20, batch 30, loss: 7.1272
# epoch 6/20, batch 40, loss: 7.1791
# epoch 6/20, batch 50, loss: 7.0112
# epoch 6/20, batch 60, loss: 7.2624
# epoch 6/20, batch 70, loss: 6.9591
# epoch 6/20, batch 80, loss: 7.4454
# epoch 6/20, batch 90, loss: 7.0313
# epoch 6/20, batch 100, loss: 6.9960
# epoch 6/20, batch 110, loss: 7.1600
# epoch 6/20, batch 120, loss: 7.1812
# epoch 6/20, avg Loss: 7.1974
# epoch 7/20, batch 0, loss: 7.0028
# epoch 7/20, batch 10, loss: 7.1789
# epoch 7/20, batch 20, loss: 7.0363
# epoch 7/20, batch 30, loss: 6.9338
# epoch 7/20, batch 40, loss: 6.7366
# epoch 7/20, batch 50, loss: 6.8328
# epoch 7/20, batch 60, loss: 7.1671
# epoch 7/20, batch 70, loss: 6.7691
# epoch 7/20, batch 80, loss: 7.0186
# epoch 7/20, batch 90, loss: 6.7975
# epoch 7/20, batch 100, loss: 6.6646
# epoch 7/20, batch 110, loss: 6.9820
# epoch 7/20, batch 120, loss: 6.8537
# epoch 7/20, avg Loss: 6.9692
# epoch 8/20, batch 0, loss: 6.7943
# epoch 8/20, batch 10, loss: 7.1676
# epoch 8/20, batch 20, loss: 6.8349
# epoch 8/20, batch 30, loss: 6.7624
# epoch 8/20, batch 40, loss: 6.5172
# epoch 8/20, batch 50, loss: 6.6124
# epoch 8/20, batch 60, loss: 6.6510
# epoch 8/20, batch 70, loss: 6.4661
# epoch 8/20, batch 80, loss: 6.9781
# epoch 8/20, batch 90, loss: 6.7688
# epoch 8/20, batch 100, loss: 6.5068
# epoch 8/20, batch 110, loss: 6.6944
# epoch 8/20, batch 120, loss: 6.5128
# epoch 8/20, avg Loss: 6.7347
# epoch 9/20, batch 0, loss: 6.5379
# epoch 9/20, batch 10, loss: 7.0206
# epoch 9/20, batch 20, loss: 6.6574
# epoch 9/20, batch 30, loss: 6.6685
# epoch 9/20, batch 40, loss: 6.3255
# epoch 9/20, batch 50, loss: 6.3810
# epoch 9/20, batch 60, loss: 6.5917
# epoch 9/20, batch 70, loss: 6.2859
# epoch 9/20, batch 80, loss: 7.1067
# epoch 9/20, batch 90, loss: 6.4800
# epoch 9/20, batch 100, loss: 6.4304
# epoch 9/20, batch 110, loss: 6.3572
# epoch 9/20, batch 120, loss: 6.1690
# epoch 9/20, avg Loss: 6.5624
# epoch 10/20, batch 0, loss: 6.1921
# epoch 10/20, batch 10, loss: 6.7668
# epoch 10/20, batch 20, loss: 6.5032
# epoch 10/20, batch 30, loss: 6.3994
# epoch 10/20, batch 40, loss: 6.1564
# epoch 10/20, batch 50, loss: 6.2669
# epoch 10/20, batch 60, loss: 6.3491
# epoch 10/20, batch 70, loss: 6.2279
# epoch 10/20, batch 80, loss: 6.6778
# epoch 10/20, batch 90, loss: 6.1052
# epoch 10/20, batch 100, loss: 6.1536
# epoch 10/20, batch 110, loss: 6.1830
# epoch 10/20, batch 120, loss: 6.0822
# epoch 10/20, avg Loss: 6.3551
# epoch 11/20, batch 0, loss: 6.0304
# epoch 11/20, batch 10, loss: 6.7665
# epoch 11/20, batch 20, loss: 6.4568
# epoch 11/20, batch 30, loss: 6.5154
# epoch 11/20, batch 40, loss: 6.1282
# epoch 11/20, batch 50, loss: 6.2121
# epoch 11/20, batch 60, loss: 6.2736
# epoch 11/20, batch 70, loss: 6.2522
# epoch 11/20, batch 80, loss: 6.5321
# epoch 11/20, batch 90, loss: 6.0263
# epoch 11/20, batch 100, loss: 6.0720
# epoch 11/20, batch 110, loss: 6.1353
# epoch 11/20, batch 120, loss: 6.0524
# epoch 11/20, avg Loss: 6.2920
# epoch 12/20, batch 0, loss: 6.0530
# epoch 12/20, batch 10, loss: 6.6921
# epoch 12/20, batch 20, loss: 6.5715
# epoch 12/20, batch 30, loss: 6.2336
# epoch 12/20, batch 40, loss: 6.1876
# epoch 12/20, batch 50, loss: 6.2683
# epoch 12/20, batch 60, loss: 6.2822
# epoch 12/20, batch 70, loss: 5.9651
# epoch 12/20, batch 80, loss: 6.2632
# epoch 12/20, batch 90, loss: 5.8432
# epoch 12/20, batch 100, loss: 6.0622
# epoch 12/20, batch 110, loss: 6.0380
# epoch 12/20, batch 120, loss: 5.8568
# epoch 12/20, avg Loss: 6.2177
# epoch 13/20, batch 0, loss: 6.1038
# epoch 13/20, batch 10, loss: 6.5848
# epoch 13/20, batch 20, loss: 6.5072
# epoch 13/20, batch 30, loss: 6.1128
# epoch 13/20, batch 40, loss: 5.9889
# epoch 13/20, batch 50, loss: 6.2993
# epoch 13/20, batch 60, loss: 6.4372
# epoch 13/20, batch 70, loss: 5.9308
# epoch 13/20, batch 80, loss: 6.3826
# epoch 13/20, batch 90, loss: 5.7578
# epoch 13/20, batch 100, loss: 5.9278
# epoch 13/20, batch 110, loss: 5.7999
# epoch 13/20, batch 120, loss: 5.6610
# epoch 13/20, avg Loss: 6.0991
# epoch 14/20, batch 0, loss: 5.7575
# epoch 14/20, batch 10, loss: 6.4475
# epoch 14/20, batch 20, loss: 6.2201
# epoch 14/20, batch 30, loss: 6.2726
# epoch 14/20, batch 40, loss: 6.2395
# epoch 14/20, batch 50, loss: 6.0215
# epoch 14/20, batch 60, loss: 5.9850
# epoch 14/20, batch 70, loss: 5.9080
# epoch 14/20, batch 80, loss: 6.1691
# epoch 14/20, batch 90, loss: 5.5861
# epoch 14/20, batch 100, loss: 5.5927
# epoch 14/20, batch 110, loss: 5.9729
# epoch 14/20, batch 120, loss: 5.7375
# epoch 14/20, avg Loss: 6.0020
# epoch 15/20, batch 0, loss: 5.7793
# epoch 15/20, batch 10, loss: 6.5082
# epoch 15/20, batch 20, loss: 6.1147
# epoch 15/20, batch 30, loss: 6.0598
# epoch 15/20, batch 40, loss: 5.9898
# epoch 15/20, batch 50, loss: 5.7459
# epoch 15/20, batch 60, loss: 6.0712
# epoch 15/20, batch 70, loss: 5.7033
# epoch 15/20, batch 80, loss: 5.9865
# epoch 15/20, batch 90, loss: 5.5861
# epoch 15/20, batch 100, loss: 5.4706
# epoch 15/20, batch 110, loss: 5.6394
# epoch 15/20, batch 120, loss: 5.5433
# epoch 15/20, avg Loss: 5.8388
# epoch 16/20, batch 0, loss: 5.4800
# epoch 16/20, batch 10, loss: 6.0649
# epoch 16/20, batch 20, loss: 5.9098
# epoch 16/20, batch 30, loss: 5.7036
# epoch 16/20, batch 40, loss: 5.6527
# epoch 16/20, batch 50, loss: 5.5751
# epoch 16/20, batch 60, loss: 5.6546
# epoch 16/20, batch 70, loss: 5.5298
# epoch 16/20, batch 80, loss: 5.8188
# epoch 16/20, batch 90, loss: 5.4150
# epoch 16/20, batch 100, loss: 5.1881
# epoch 16/20, batch 110, loss: 5.4091
# epoch 16/20, batch 120, loss: 5.3381
# epoch 16/20, avg Loss: 5.5913
# epoch 17/20, batch 0, loss: 5.4352
# epoch 17/20, batch 10, loss: 5.9595
# epoch 17/20, batch 20, loss: 5.7199
# epoch 17/20, batch 30, loss: 5.5825
# epoch 17/20, batch 40, loss: 5.4995
# epoch 17/20, batch 50, loss: 5.3915
# epoch 17/20, batch 60, loss: 5.5366
# epoch 17/20, batch 70, loss: 5.3253
# epoch 17/20, batch 80, loss: 5.6776
# epoch 17/20, batch 90, loss: 5.2078
# epoch 17/20, batch 100, loss: 5.1906
# epoch 17/20, batch 110, loss: 5.7706
# epoch 17/20, batch 120, loss: 5.2095
# epoch 17/20, avg Loss: 5.4653
# epoch 18/20, batch 0, loss: 5.1460
# epoch 18/20, batch 10, loss: 5.7315
# epoch 18/20, batch 20, loss: 5.7099
# epoch 18/20, batch 30, loss: 5.9653
# epoch 18/20, batch 40, loss: 5.5612
# epoch 18/20, batch 50, loss: 5.4358
# epoch 18/20, batch 60, loss: 5.3968
# epoch 18/20, batch 70, loss: 5.3327
# epoch 18/20, batch 80, loss: 5.5633
# epoch 18/20, batch 90, loss: 5.2486
# epoch 18/20, batch 100, loss: 4.9739
# epoch 18/20, batch 110, loss: 5.4219
# epoch 18/20, batch 120, loss: 5.0508
# epoch 18/20, avg Loss: 5.4377
# epoch 19/20, batch 0, loss: 5.0417
# epoch 19/20, batch 10, loss: 5.9538
# epoch 19/20, batch 20, loss: 5.9969
# epoch 19/20, batch 30, loss: 5.5083
# epoch 19/20, batch 40, loss: 5.2829
# epoch 19/20, batch 50, loss: 5.8037
# epoch 19/20, batch 60, loss: 6.2407
# epoch 19/20, batch 70, loss: 6.2446
# epoch 19/20, batch 80, loss: 6.3489
# epoch 19/20, batch 90, loss: 6.1425
# epoch 19/20, batch 100, loss: 6.2876
# epoch 19/20, batch 110, loss: 6.1365
# epoch 19/20, batch 120, loss: 5.8276
# epoch 19/20, avg Loss: 5.9288
# epoch 20/20, batch 0, loss: 5.9827
# epoch 20/20, batch 10, loss: 6.3403
# epoch 20/20, batch 20, loss: 6.2459
# epoch 20/20, batch 30, loss: 6.2111
# epoch 20/20, batch 40, loss: 5.8980
# epoch 20/20, batch 50, loss: 6.0100
# epoch 20/20, batch 60, loss: 5.8950
# epoch 20/20, batch 70, loss: 5.6632
# epoch 20/20, batch 80, loss: 5.7661
# epoch 20/20, batch 90, loss: 5.4980
# epoch 20/20, batch 100, loss: 5.4309
# epoch 20/20, batch 110, loss: 5.7697
# epoch 20/20, batch 120, loss: 5.4684
# epoch 20/20, avg Loss: 5.8341

# %%
plt.plot(range(1, num_epochs + 1), losses)
plt.xlabel('эпохи')
plt.ylabel('лосс')
plt.title('LSTM')
plt.show()

# %%
def generate_text(model, start_text, length=50):
    model.eval()
    words = start_text.split()
    inputs = torch.tensor(text_to_sequence(' '.join(words), vocab), dtype=torch.long).unsqueeze(0).to(device)
    generated_text = start_text

    with torch.no_grad():
        for _ in range(length):
            output = model(inputs)
            _, predicted_idx = torch.max(output, dim=1)
            predicted_word = reverse_vocab[predicted_idx.item()]
            generated_text += ' ' + predicted_word

            words.append(predicted_word)
            inputs = torch.tensor(text_to_sequence(' '.join(words[-seq_length:]), vocab), dtype=torch.long).unsqueeze(0).to(device)

    return generated_text

start_text = "сегодня в анекдоте"
generated_text = generate_text(model, start_text)
print(generated_text)
# Out:
# сегодня в анекдоте щелей <|startoftext|>парень шумят.- на на год на этот в кино и не туда, и слов. козу?- на искусственная спасет в собой и будет. козу?- крыма а я не сериале спасет в правой, и это в самоспаривающиеся носки! и двери а это не сериале отражение вилка мама завалены московского перерыв должен

# %%
# обработка текста v2
import re

with open("anek_djvu.txt", "r", encoding="utf-8") as f:
    text = f.read()

# удалим все, кроме кириллических букв и пробелов
text = text.lower()
text = re.sub(r'[^а-яё\s]', '', text)
tokens = text.split()

# ограничим словарь топ-10К частотных слов
max_vocab_size = 10000
word_counts = Counter(tokens)
most_common_words = word_counts.most_common(max_vocab_size - 1)
vocab = {word: idx + 1 for idx, (word, _) in enumerate(most_common_words)}
vocab["<UNK>"] = 0
reverse_vocab = {idx: word for word, idx in vocab.items()}

vocab_size = len(vocab)
print(f"размер словаря {vocab_size}")
# Out:
# размер словаря 10000

# %%
def text_to_sequence(text, vocab):
    return [vocab.get(word, 0) for word in text.split()]

sequence = text_to_sequence(text, vocab)
max_tokens = 20000
sequence = sequence[:max_tokens]
seq_length = 30
X = []
y = []

for i in range(len(sequence) - seq_length):
    X.append(sequence[i:i + seq_length])
    y.append(sequence[i + seq_length])

X = torch.tensor(X, dtype=torch.long)
y = torch.tensor(y, dtype=torch.long)

train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers=1):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x):
        embedded = self.embedding(x)
        lstm_out, _ = self.lstm(embedded)
        output = self.fc(lstm_out[:, -1, :])
        return output

# %%
# параметры и обучение
embedding_dim = 256
hidden_dim = 256
num_layers = 1
model = LSTMModel(vocab_size, embedding_dim, hidden_dim, num_layers).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

batch_size = 64
num_epochs = 20
losses = []

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for i in range(0, len(X_train), batch_size):
        inputs = X_train[i:i + batch_size].to(device)
        targets = y_train[i:i + batch_size].to(device)

        optimizer.zero_grad()

        output = model(inputs)
        loss = criterion(output, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5)

        optimizer.step()
        total_loss += loss.item()

        if i % (batch_size * 10) == 0:
            print(f"epoch {epoch+1}/{num_epochs}, batch {i//batch_size}, loss: {loss.item():.4f}")

    avg_loss = total_loss / (len(X_train) // batch_size)
    losses.append(avg_loss)
    print(f"epoch {epoch+1}/{num_epochs}, avg loss: {avg_loss:.4f}")
# Out:
# epoch 1/20, batch 0, loss: 9.2435
# epoch 1/20, batch 10, loss: 9.0985
# epoch 1/20, batch 20, loss: 7.6207
# epoch 1/20, batch 30, loss: 6.3523
# epoch 1/20, batch 40, loss: 6.8976
# epoch 1/20, batch 50, loss: 6.7558
# epoch 1/20, batch 60, loss: 5.6186
# epoch 1/20, batch 70, loss: 6.8285
# epoch 1/20, batch 80, loss: 6.9150
# epoch 1/20, batch 90, loss: 6.3036
# epoch 1/20, batch 100, loss: 6.2834
# epoch 1/20, batch 110, loss: 7.1890
# epoch 1/20, batch 120, loss: 6.7584
# epoch 1/20, batch 130, loss: 6.4057
# epoch 1/20, batch 140, loss: 6.7584
# epoch 1/20, batch 150, loss: 6.4708
# epoch 1/20, batch 160, loss: 5.6392
# epoch 1/20, batch 170, loss: 5.9370
# epoch 1/20, batch 180, loss: 6.2624
# epoch 1/20, batch 190, loss: 5.4705
# epoch 1/20, batch 200, loss: 6.4449
# epoch 1/20, batch 210, loss: 5.6796
# epoch 1/20, batch 220, loss: 6.6496
# epoch 1/20, batch 230, loss: 6.9535
# epoch 1/20, batch 240, loss: 5.9668
# epoch 1/20, avg loss: 6.7988
# epoch 2/20, batch 0, loss: 5.8909
# epoch 2/20, batch 10, loss: 5.7141
# epoch 2/20, batch 20, loss: 6.1088
# epoch 2/20, batch 30, loss: 5.4338
# epoch 2/20, batch 40, loss: 5.9372
# epoch 2/20, batch 50, loss: 5.8475
# epoch 2/20, batch 60, loss: 5.0726
# epoch 2/20, batch 70, loss: 6.1603
# epoch 2/20, batch 80, loss: 6.1059
# epoch 2/20, batch 90, loss: 5.7241
# epoch 2/20, batch 100, loss: 5.6571
# epoch 2/20, batch 110, loss: 6.4608
# epoch 2/20, batch 120, loss: 6.0251
# epoch 2/20, batch 130, loss: 5.9104
# epoch 2/20, batch 140, loss: 6.0688
# epoch 2/20, batch 150, loss: 5.7535
# epoch 2/20, batch 160, loss: 5.1608
# epoch 2/20, batch 170, loss: 5.3093
# epoch 2/20, batch 180, loss: 5.7971
# epoch 2/20, batch 190, loss: 4.8696
# epoch 2/20, batch 200, loss: 6.0002
# epoch 2/20, batch 210, loss: 5.1048
# epoch 2/20, batch 220, loss: 5.8368
# epoch 2/20, batch 230, loss: 6.2010
# epoch 2/20, batch 240, loss: 5.4521
# epoch 2/20, avg loss: 5.8442
# epoch 3/20, batch 0, loss: 5.4585
# epoch 3/20, batch 10, loss: 5.3359
# epoch 3/20, batch 20, loss: 5.8959
# epoch 3/20, batch 30, loss: 5.3292
# epoch 3/20, batch 40, loss: 5.6333
# epoch 3/20, batch 50, loss: 5.4653
# epoch 3/20, batch 60, loss: 4.8480
# epoch 3/20, batch 70, loss: 5.8717
# epoch 3/20, batch 80, loss: 5.7451
# epoch 3/20, batch 90, loss: 5.3335
# epoch 3/20, batch 100, loss: 5.2720
# epoch 3/20, batch 110, loss: 5.8751
# epoch 3/20, batch 120, loss: 5.5804
# epoch 3/20, batch 130, loss: 5.5077
# epoch 3/20, batch 140, loss: 5.5647
# epoch 3/20, batch 150, loss: 5.2343
# epoch 3/20, batch 160, loss: 4.7963
# epoch 3/20, batch 170, loss: 4.8791
# epoch 3/20, batch 180, loss: 5.3074
# epoch 3/20, batch 190, loss: 4.4155
# epoch 3/20, batch 200, loss: 5.4084
# epoch 3/20, batch 210, loss: 4.6332
# epoch 3/20, batch 220, loss: 5.1167
# epoch 3/20, batch 230, loss: 5.4697
# epoch 3/20, batch 240, loss: 4.8522
# epoch 3/20, avg loss: 5.3660
# epoch 4/20, batch 0, loss: 4.8436
# epoch 4/20, batch 10, loss: 4.7123
# epoch 4/20, batch 20, loss: 5.3185
# epoch 4/20, batch 30, loss: 4.9865
# epoch 4/20, batch 40, loss: 5.2504
# epoch 4/20, batch 50, loss: 5.2041
# epoch 4/20, batch 60, loss: 4.5686
# epoch 4/20, batch 70, loss: 5.4710
# epoch 4/20, batch 80, loss: 5.3383
# epoch 4/20, batch 90, loss: 4.9910
# epoch 4/20, batch 100, loss: 4.8768
# epoch 4/20, batch 110, loss: 5.2637
# epoch 4/20, batch 120, loss: 5.0883
# epoch 4/20, batch 130, loss: 5.1046
# epoch 4/20, batch 140, loss: 5.1524
# epoch 4/20, batch 150, loss: 4.7228
# epoch 4/20, batch 160, loss: 4.4805
# epoch 4/20, batch 170, loss: 4.4479
# epoch 4/20, batch 180, loss: 4.8385
# epoch 4/20, batch 190, loss: 4.0491
# epoch 4/20, batch 200, loss: 5.0268
# epoch 4/20, batch 210, loss: 4.1794
# epoch 4/20, batch 220, loss: 4.4871
# epoch 4/20, batch 230, loss: 4.8775
# epoch 4/20, batch 240, loss: 4.3550
# epoch 4/20, avg loss: 4.8835
# epoch 5/20, batch 0, loss: 4.1880
# epoch 5/20, batch 10, loss: 4.0985
# epoch 5/20, batch 20, loss: 4.5658
# epoch 5/20, batch 30, loss: 4.5269
# epoch 5/20, batch 40, loss: 4.9106
# epoch 5/20, batch 50, loss: 4.6705
# epoch 5/20, batch 60, loss: 4.2525
# epoch 5/20, batch 70, loss: 4.9775
# epoch 5/20, batch 80, loss: 4.8054
# epoch 5/20, batch 90, loss: 4.5449
# epoch 5/20, batch 100, loss: 4.4988
# epoch 5/20, batch 110, loss: 4.7330
# epoch 5/20, batch 120, loss: 4.6635
# epoch 5/20, batch 130, loss: 4.6951
# epoch 5/20, batch 140, loss: 4.6593
# epoch 5/20, batch 150, loss: 4.1101
# epoch 5/20, batch 160, loss: 4.1447
# epoch 5/20, batch 170, loss: 4.1023
# epoch 5/20, batch 180, loss: 4.3838
# epoch 5/20, batch 190, loss: 3.6792
# epoch 5/20, batch 200, loss: 4.4825
# epoch 5/20, batch 210, loss: 3.6790
# epoch 5/20, batch 220, loss: 3.8866
# epoch 5/20, batch 230, loss: 4.1999
# epoch 5/20, batch 240, loss: 3.6886
# epoch 5/20, avg loss: 4.3420
# epoch 6/20, batch 0, loss: 3.7330
# epoch 6/20, batch 10, loss: 3.5668
# epoch 6/20, batch 20, loss: 3.7278
# epoch 6/20, batch 30, loss: 4.0553
# epoch 6/20, batch 40, loss: 4.3318
# epoch 6/20, batch 50, loss: 4.1220
# epoch 6/20, batch 60, loss: 3.8083
# epoch 6/20, batch 70, loss: 4.4641
# epoch 6/20, batch 80, loss: 4.2268
# epoch 6/20, batch 90, loss: 4.0681
# epoch 6/20, batch 100, loss: 4.0039
# epoch 6/20, batch 110, loss: 4.0162
# epoch 6/20, batch 120, loss: 3.9508
# epoch 6/20, batch 130, loss: 4.0692
# epoch 6/20, batch 140, loss: 4.0697
# epoch 6/20, batch 150, loss: 3.6476
# epoch 6/20, batch 160, loss: 3.6594
# epoch 6/20, batch 170, loss: 3.4705
# epoch 6/20, batch 180, loss: 3.7477
# epoch 6/20, batch 190, loss: 3.2758
# epoch 6/20, batch 200, loss: 3.8648
# epoch 6/20, batch 210, loss: 3.2762
# epoch 6/20, batch 220, loss: 3.2053
# epoch 6/20, batch 230, loss: 3.4922
# epoch 6/20, batch 240, loss: 3.1580
# epoch 6/20, avg loss: 3.7689
# epoch 7/20, batch 0, loss: 3.2016
# epoch 7/20, batch 10, loss: 2.9297
# epoch 7/20, batch 20, loss: 3.1195
# epoch 7/20, batch 30, loss: 3.5131
# epoch 7/20, batch 40, loss: 3.7641
# epoch 7/20, batch 50, loss: 3.6399
# epoch 7/20, batch 60, loss: 3.4849
# epoch 7/20, batch 70, loss: 4.0390
# epoch 7/20, batch 80, loss: 3.6532
# epoch 7/20, batch 90, loss: 3.5618
# epoch 7/20, batch 100, loss: 3.4835
# epoch 7/20, batch 110, loss: 3.3543
# epoch 7/20, batch 120, loss: 3.3847
# epoch 7/20, batch 130, loss: 3.6430
# epoch 7/20, batch 140, loss: 3.5028
# epoch 7/20, batch 150, loss: 3.1838
# epoch 7/20, batch 160, loss: 3.2719
# epoch 7/20, batch 170, loss: 3.1668
# epoch 7/20, batch 180, loss: 3.3506
# epoch 7/20, batch 190, loss: 3.0320
# epoch 7/20, batch 200, loss: 3.3021
# epoch 7/20, batch 210, loss: 3.0082
# epoch 7/20, batch 220, loss: 2.5781
# epoch 7/20, batch 230, loss: 2.9441
# epoch 7/20, batch 240, loss: 2.7804
# epoch 7/20, avg loss: 3.2639
# epoch 8/20, batch 0, loss: 2.8577
# epoch 8/20, batch 10, loss: 2.5927
# epoch 8/20, batch 20, loss: 2.5277
# epoch 8/20, batch 30, loss: 3.4014
# epoch 8/20, batch 40, loss: 3.3934
# epoch 8/20, batch 50, loss: 3.1699
# epoch 8/20, batch 60, loss: 3.3776
# epoch 8/20, batch 70, loss: 3.4349
# epoch 8/20, batch 80, loss: 3.0922
# epoch 8/20, batch 90, loss: 3.0824
# epoch 8/20, batch 100, loss: 3.2340
# epoch 8/20, batch 110, loss: 2.8962
# epoch 8/20, batch 120, loss: 2.9156
# epoch 8/20, batch 130, loss: 3.1641
# epoch 8/20, batch 140, loss: 2.8821
# epoch 8/20, batch 150, loss: 2.8671
# epoch 8/20, batch 160, loss: 2.7562
# epoch 8/20, batch 170, loss: 2.5525
# epoch 8/20, batch 180, loss: 2.7071
# epoch 8/20, batch 190, loss: 2.6850
# epoch 8/20, batch 200, loss: 2.6195
# epoch 8/20, batch 210, loss: 2.5482
# epoch 8/20, batch 220, loss: 2.0000
# epoch 8/20, batch 230, loss: 2.3690
# epoch 8/20, batch 240, loss: 2.3241
# epoch 8/20, avg loss: 2.7783
# epoch 9/20, batch 0, loss: 2.3578
# epoch 9/20, batch 10, loss: 2.0900
# epoch 9/20, batch 20, loss: 1.8473
# epoch 9/20, batch 30, loss: 2.6983
# epoch 9/20, batch 40, loss: 3.0502
# epoch 9/20, batch 50, loss: 2.7937
# epoch 9/20, batch 60, loss: 2.9442
# epoch 9/20, batch 70, loss: 2.9178
# epoch 9/20, batch 80, loss: 2.7851
# epoch 9/20, batch 90, loss: 2.7414
# epoch 9/20, batch 100, loss: 2.8600
# epoch 9/20, batch 110, loss: 2.4049
# epoch 9/20, batch 120, loss: 2.3429
# epoch 9/20, batch 130, loss: 2.7922
# epoch 9/20, batch 140, loss: 2.4817
# epoch 9/20, batch 150, loss: 2.4039
# epoch 9/20, batch 160, loss: 2.3292
# epoch 9/20, batch 170, loss: 2.1999
# epoch 9/20, batch 180, loss: 2.2764
# epoch 9/20, batch 190, loss: 2.2449
# epoch 9/20, batch 200, loss: 2.3308
# epoch 9/20, batch 210, loss: 2.2359
# epoch 9/20, batch 220, loss: 1.6373
# epoch 9/20, batch 230, loss: 1.9046
# epoch 9/20, batch 240, loss: 1.8740
# epoch 9/20, avg loss: 2.3545
# epoch 10/20, batch 0, loss: 1.7899
# epoch 10/20, batch 10, loss: 1.8883
# epoch 10/20, batch 20, loss: 1.5012
# epoch 10/20, batch 30, loss: 2.1567
# epoch 10/20, batch 40, loss: 2.4159
# epoch 10/20, batch 50, loss: 2.3873
# epoch 10/20, batch 60, loss: 2.7728
# epoch 10/20, batch 70, loss: 2.4616
# epoch 10/20, batch 80, loss: 2.2619
# epoch 10/20, batch 90, loss: 2.2326
# epoch 10/20, batch 100, loss: 2.4616
# epoch 10/20, batch 110, loss: 1.8725
# epoch 10/20, batch 120, loss: 1.8950
# epoch 10/20, batch 130, loss: 2.2516
# epoch 10/20, batch 140, loss: 2.0189
# epoch 10/20, batch 150, loss: 1.9198
# epoch 10/20, batch 160, loss: 1.9315
# epoch 10/20, batch 170, loss: 1.8179
# epoch 10/20, batch 180, loss: 1.9352
# epoch 10/20, batch 190, loss: 1.8769
# epoch 10/20, batch 200, loss: 1.7488
# epoch 10/20, batch 210, loss: 1.8934
# epoch 10/20, batch 220, loss: 1.3515
# epoch 10/20, batch 230, loss: 1.5571
# epoch 10/20, batch 240, loss: 1.5008
# epoch 10/20, avg loss: 1.9520
# epoch 11/20, batch 0, loss: 1.4827
# epoch 11/20, batch 10, loss: 1.4481
# epoch 11/20, batch 20, loss: 1.1434
# epoch 11/20, batch 30, loss: 1.9084
# epoch 11/20, batch 40, loss: 2.1638
# epoch 11/20, batch 50, loss: 2.0801
# epoch 11/20, batch 60, loss: 2.3503
# epoch 11/20, batch 70, loss: 2.0877
# epoch 11/20, batch 80, loss: 1.7926
# epoch 11/20, batch 90, loss: 1.9412
# epoch 11/20, batch 100, loss: 2.1603
# epoch 11/20, batch 110, loss: 1.6180
# epoch 11/20, batch 120, loss: 1.5547
# epoch 11/20, batch 130, loss: 1.9386
# epoch 11/20, batch 140, loss: 1.7169
# epoch 11/20, batch 150, loss: 1.5911
# epoch 11/20, batch 160, loss: 1.6538
# epoch 11/20, batch 170, loss: 1.4715
# epoch 11/20, batch 180, loss: 1.6160
# epoch 11/20, batch 190, loss: 1.6630
# epoch 11/20, batch 200, loss: 1.3008
# epoch 11/20, batch 210, loss: 1.4892
# epoch 11/20, batch 220, loss: 1.0681
# epoch 11/20, batch 230, loss: 1.1689
# epoch 11/20, batch 240, loss: 1.4047
# epoch 11/20, avg loss: 1.6222
# epoch 12/20, batch 0, loss: 1.2434
# epoch 12/20, batch 10, loss: 1.2582
# epoch 12/20, batch 20, loss: 0.8162
# epoch 12/20, batch 30, loss: 1.4953
# epoch 12/20, batch 40, loss: 1.6292
# epoch 12/20, batch 50, loss: 1.6384
# epoch 12/20, batch 60, loss: 2.0936
# epoch 12/20, batch 70, loss: 1.8038
# epoch 12/20, batch 80, loss: 1.4011
# epoch 12/20, batch 90, loss: 1.4599
# epoch 12/20, batch 100, loss: 1.8532
# epoch 12/20, batch 110, loss: 1.2603
# epoch 12/20, batch 120, loss: 1.3297
# epoch 12/20, batch 130, loss: 1.7219
# epoch 12/20, batch 140, loss: 1.4740
# epoch 12/20, batch 150, loss: 1.4019
# epoch 12/20, batch 160, loss: 1.5004
# epoch 12/20, batch 170, loss: 1.3556
# epoch 12/20, batch 180, loss: 1.2285
# epoch 12/20, batch 190, loss: 1.3783
# epoch 12/20, batch 200, loss: 1.0754
# epoch 12/20, batch 210, loss: 1.4356
# epoch 12/20, batch 220, loss: 0.8814
# epoch 12/20, batch 230, loss: 1.0504
# epoch 12/20, batch 240, loss: 1.1937
# epoch 12/20, avg loss: 1.3726
# epoch 13/20, batch 0, loss: 1.2518
# epoch 13/20, batch 10, loss: 1.1672
# epoch 13/20, batch 20, loss: 0.6960
# epoch 13/20, batch 30, loss: 1.2761
# epoch 13/20, batch 40, loss: 1.4444
# epoch 13/20, batch 50, loss: 1.5064
# epoch 13/20, batch 60, loss: 1.7800
# epoch 13/20, batch 70, loss: 1.5445
# epoch 13/20, batch 80, loss: 1.5069
# epoch 13/20, batch 90, loss: 1.4162
# epoch 13/20, batch 100, loss: 1.8051
# epoch 13/20, batch 110, loss: 1.2524
# epoch 13/20, batch 120, loss: 1.3299
# epoch 13/20, batch 130, loss: 1.5680
# epoch 13/20, batch 140, loss: 1.2723
# epoch 13/20, batch 150, loss: 1.2188
# epoch 13/20, batch 160, loss: 1.1826
# epoch 13/20, batch 170, loss: 1.1325
# epoch 13/20, batch 180, loss: 1.1725
# epoch 13/20, batch 190, loss: 1.2472
# epoch 13/20, batch 200, loss: 0.7952
# epoch 13/20, batch 210, loss: 1.2166
# epoch 13/20, batch 220, loss: 0.9232
# epoch 13/20, batch 230, loss: 0.7612
# epoch 13/20, batch 240, loss: 1.1424
# epoch 13/20, avg loss: 1.2254
# epoch 14/20, batch 0, loss: 1.0344
# epoch 14/20, batch 10, loss: 1.0342
# epoch 14/20, batch 20, loss: 0.8655
# epoch 14/20, batch 30, loss: 1.1009
# epoch 14/20, batch 40, loss: 1.2367
# epoch 14/20, batch 50, loss: 1.2804
# epoch 14/20, batch 60, loss: 1.4121
# epoch 14/20, batch 70, loss: 1.0755
# epoch 14/20, batch 80, loss: 0.9938
# epoch 14/20, batch 90, loss: 1.1701
# epoch 14/20, batch 100, loss: 1.3209
# epoch 14/20, batch 110, loss: 0.8823
# epoch 14/20, batch 120, loss: 0.9251
# epoch 14/20, batch 130, loss: 1.2942
# epoch 14/20, batch 140, loss: 1.3767
# epoch 14/20, batch 150, loss: 0.8762
# epoch 14/20, batch 160, loss: 1.1865
# epoch 14/20, batch 170, loss: 1.1293
# epoch 14/20, batch 180, loss: 0.9903
# epoch 14/20, batch 190, loss: 1.0649
# epoch 14/20, batch 200, loss: 0.6211
# epoch 14/20, batch 210, loss: 0.9067
# epoch 14/20, batch 220, loss: 0.5872
# epoch 14/20, batch 230, loss: 0.5452
# epoch 14/20, batch 240, loss: 0.9574
# epoch 14/20, avg loss: 1.0030
# epoch 15/20, batch 0, loss: 0.8723
# epoch 15/20, batch 10, loss: 0.7354
# epoch 15/20, batch 20, loss: 0.6172
# epoch 15/20, batch 30, loss: 0.8632
# epoch 15/20, batch 40, loss: 1.0002
# epoch 15/20, batch 50, loss: 1.0815
# epoch 15/20, batch 60, loss: 1.1864
# epoch 15/20, batch 70, loss: 0.9011
# epoch 15/20, batch 80, loss: 0.9367
# epoch 15/20, batch 90, loss: 0.9807
# epoch 15/20, batch 100, loss: 1.0494
# epoch 15/20, batch 110, loss: 0.7420
# epoch 15/20, batch 120, loss: 0.8750
# epoch 15/20, batch 130, loss: 1.1314
# epoch 15/20, batch 140, loss: 0.8838
# epoch 15/20, batch 150, loss: 0.7894
# epoch 15/20, batch 160, loss: 0.9061
# epoch 15/20, batch 170, loss: 0.8878
# epoch 15/20, batch 180, loss: 0.7518
# epoch 15/20, batch 190, loss: 0.8587
# epoch 15/20, batch 200, loss: 0.5071
# epoch 15/20, batch 210, loss: 0.8019
# epoch 15/20, batch 220, loss: 0.6205
# epoch 15/20, batch 230, loss: 0.4464
# epoch 15/20, batch 240, loss: 0.8758
# epoch 15/20, avg loss: 0.7995
# epoch 16/20, batch 0, loss: 0.6845
# epoch 16/20, batch 10, loss: 0.5882
# epoch 16/20, batch 20, loss: 0.5212
# epoch 16/20, batch 30, loss: 0.9160
# epoch 16/20, batch 40, loss: 0.8367
# epoch 16/20, batch 50, loss: 0.8462
# epoch 16/20, batch 60, loss: 1.1597
# epoch 16/20, batch 70, loss: 0.9170
# epoch 16/20, batch 80, loss: 0.6621
# epoch 16/20, batch 90, loss: 0.7755
# epoch 16/20, batch 100, loss: 0.9976
# epoch 16/20, batch 110, loss: 0.6646
# epoch 16/20, batch 120, loss: 0.8532
# epoch 16/20, batch 130, loss: 0.9337
# epoch 16/20, batch 140, loss: 0.6986
# epoch 16/20, batch 150, loss: 0.6479
# epoch 16/20, batch 160, loss: 0.7199
# epoch 16/20, batch 170, loss: 0.6723
# epoch 16/20, batch 180, loss: 0.7377
# epoch 16/20, batch 190, loss: 0.7550
# epoch 16/20, batch 200, loss: 0.4219
# epoch 16/20, batch 210, loss: 0.6292
# epoch 16/20, batch 220, loss: 0.3895
# epoch 16/20, batch 230, loss: 0.2965
# epoch 16/20, batch 240, loss: 0.5222
# epoch 16/20, avg loss: 0.6864
# epoch 17/20, batch 0, loss: 0.4730
# epoch 17/20, batch 10, loss: 0.4687
# epoch 17/20, batch 20, loss: 0.3682
# epoch 17/20, batch 30, loss: 0.5982
# epoch 17/20, batch 40, loss: 0.6467
# epoch 17/20, batch 50, loss: 0.7003
# epoch 17/20, batch 60, loss: 1.1393
# epoch 17/20, batch 70, loss: 0.6878
# epoch 17/20, batch 80, loss: 0.6319
# epoch 17/20, batch 90, loss: 0.5805
# epoch 17/20, batch 100, loss: 0.7061
# epoch 17/20, batch 110, loss: 0.4482
# epoch 17/20, batch 120, loss: 0.5236
# epoch 17/20, batch 130, loss: 0.7148
# epoch 17/20, batch 140, loss: 0.4954
# epoch 17/20, batch 150, loss: 0.4755
# epoch 17/20, batch 160, loss: 0.6577
# epoch 17/20, batch 170, loss: 0.4187
# epoch 17/20, batch 180, loss: 0.4579
# epoch 17/20, batch 190, loss: 0.5503
# epoch 17/20, batch 200, loss: 0.2405
# epoch 17/20, batch 210, loss: 0.4778
# epoch 17/20, batch 220, loss: 0.2751
# epoch 17/20, batch 230, loss: 0.2173
# epoch 17/20, batch 240, loss: 0.4584
# epoch 17/20, avg loss: 0.4917
# epoch 18/20, batch 0, loss: 0.3792
# epoch 18/20, batch 10, loss: 0.3422
# epoch 18/20, batch 20, loss: 0.1928
# epoch 18/20, batch 30, loss: 0.3887
# epoch 18/20, batch 40, loss: 0.3549
# epoch 18/20, batch 50, loss: 0.4949
# epoch 18/20, batch 60, loss: 0.8554
# epoch 18/20, batch 70, loss: 0.4522
# epoch 18/20, batch 80, loss: 0.2969
# epoch 18/20, batch 90, loss: 0.4785
# epoch 18/20, batch 100, loss: 0.4436
# epoch 18/20, batch 110, loss: 0.3114
# epoch 18/20, batch 120, loss: 0.3724
# epoch 18/20, batch 130, loss: 0.4710
# epoch 18/20, batch 140, loss: 0.3483
# epoch 18/20, batch 150, loss: 0.3442
# epoch 18/20, batch 160, loss: 0.5761
# epoch 18/20, batch 170, loss: 0.3103
# epoch 18/20, batch 180, loss: 0.2372
# epoch 18/20, batch 190, loss: 0.4194
# epoch 18/20, batch 200, loss: 0.1566
# epoch 18/20, batch 210, loss: 0.3870
# epoch 18/20, batch 220, loss: 0.2041
# epoch 18/20, batch 230, loss: 0.2133
# epoch 18/20, batch 240, loss: 0.2871
# epoch 18/20, avg loss: 0.3531
# epoch 19/20, batch 0, loss: 0.2840
# epoch 19/20, batch 10, loss: 0.2313
# epoch 19/20, batch 20, loss: 0.1613
# epoch 19/20, batch 30, loss: 0.2869
# epoch 19/20, batch 40, loss: 0.2650
# epoch 19/20, batch 50, loss: 0.5023
# epoch 19/20, batch 60, loss: 0.6607
# epoch 19/20, batch 70, loss: 0.3090
# epoch 19/20, batch 80, loss: 0.2634
# epoch 19/20, batch 90, loss: 0.3469
# epoch 19/20, batch 100, loss: 0.5510
# epoch 19/20, batch 110, loss: 0.2744
# epoch 19/20, batch 120, loss: 0.2743
# epoch 19/20, batch 130, loss: 0.3273
# epoch 19/20, batch 140, loss: 0.2998
# epoch 19/20, batch 150, loss: 0.2843
# epoch 19/20, batch 160, loss: 0.2985
# epoch 19/20, batch 170, loss: 0.2770
# epoch 19/20, batch 180, loss: 0.2307
# epoch 19/20, batch 190, loss: 0.2882
# epoch 19/20, batch 200, loss: 0.1775
# epoch 19/20, batch 210, loss: 0.2431
# epoch 19/20, batch 220, loss: 0.1250
# epoch 19/20, batch 230, loss: 0.1396
# epoch 19/20, batch 240, loss: 0.2277
# epoch 19/20, avg loss: 0.2732
# epoch 20/20, batch 0, loss: 0.2017
# epoch 20/20, batch 10, loss: 0.2045
# epoch 20/20, batch 20, loss: 0.1149
# epoch 20/20, batch 30, loss: 0.2261
# epoch 20/20, batch 40, loss: 0.2269
# epoch 20/20, batch 50, loss: 0.4162
# epoch 20/20, batch 60, loss: 0.4777
# epoch 20/20, batch 70, loss: 0.2880
# epoch 20/20, batch 80, loss: 0.2027
# epoch 20/20, batch 90, loss: 0.2335
# epoch 20/20, batch 100, loss: 0.3394
# epoch 20/20, batch 110, loss: 0.2136
# epoch 20/20, batch 120, loss: 0.2393
# epoch 20/20, batch 130, loss: 0.3663
# epoch 20/20, batch 140, loss: 0.2509
# epoch 20/20, batch 150, loss: 0.2244
# epoch 20/20, batch 160, loss: 0.2603
# epoch 20/20, batch 170, loss: 0.3577
# epoch 20/20, batch 180, loss: 0.1761
# epoch 20/20, batch 190, loss: 0.3214
# epoch 20/20, batch 200, loss: 0.1526
# epoch 20/20, batch 210, loss: 0.2169
# epoch 20/20, batch 220, loss: 0.1568
# epoch 20/20, batch 230, loss: 0.1002
# epoch 20/20, batch 240, loss: 0.1409
# epoch 20/20, avg loss: 0.2264

# %%
plt.plot(range(1, num_epochs + 1), losses)
plt.xlabel('эпохи')
plt.ylabel('лосс')
plt.title('LSTM v2')
plt.show()

# %%
def generate_text(model, start_text, length=50):
    model.eval()
    words = start_text.split()
    inputs = torch.tensor(text_to_sequence(' '.join(words), vocab), dtype=torch.long).unsqueeze(0).to(device)
    generated_text = start_text

    with torch.no_grad():
        for _ in range(length):
            output = model(inputs)
            _, predicted_idx = torch.max(output, dim=1)
            predicted_word = reverse_vocab.get(predicted_idx.item(), "<UNK>")
            generated_text += ' ' + predicted_word

            words.append(predicted_word)
            inputs = torch.tensor(text_to_sequence(' '.join(words[-seq_length:]), vocab), dtype=torch.long).unsqueeze(0).to(device)

    return generated_text

start_text = "сегодня в анекдоте"
generated_text = generate_text(model, start_text)
print(generated_text)
# Out:
# сегодня в анекдоте <UNK> <UNK> в <UNK> состоянии язык <UNK> к <UNK> а не лежит внизу <UNK> рта дождь и ветер так сильно <UNK> <UNK> что она решила не ходить на этих выходных на <UNK> вечеринку бл <UNK> в <UNK> забыл <UNK> теперь вы понимаете про кого была песня замечательный мужик меня <UNK>
